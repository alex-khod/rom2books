# %%
# !java -version

# %%
# !kaitai-struct-compiler

# %%
import os
# Compile for Python
ksy_path = os.path.join("..","src", "formats", "orom-file-formats", "KSY")
out_dir = os.path.join("..","src", "formats", "autogenerated")
# !kaitai-struct-compiler -t python {os.path.join(ksy_path, "rom_2_alm.ksy")} -d {out_dir}
# !kaitai-struct-compiler -t python {os.path.join(ksy_path, "rom_res.ksy")} -d {out_dir}
# !kaitai-struct-compiler -t python {os.path.join(ksy_path, "rom_reg.ksy")} -d {out_dir}

# %%
# Compile for CPP
ksy_path = os.path.join("..","src", "formats", "orom-file-formats", "KSY")
out_dir = os.path.join("..","src","formats", "autogenerated")
# !kaitai-struct-compiler -t cpp_stl {os.path.join(ksy_path, "rom_res.ksy")} -d {out_dir}
# !kaitai-struct-compiler -t cpp_stl {os.path.join(ksy_path, "images", "rom_256.ksy")} -d {out_dir}
